# %%
import requests
from bs4 import BeautifulSoup
from scrapfly import ScrapflyClient, ScrapeConfig
import re
import json

api_key = 'scp-live-01fc8534987042f4a2fe553c5cf6a2df'
scrapfly = ScrapflyClient(key=api_key, max_concurrency=2)
url = 'https://www.samsung.com/in/monitors/smart/smart-monitor-m7-32-inch-smart-tv-apps-ls32dm700uwxxl/'
result = scrapfly.scrape(ScrapeConfig(
    url=url,
    render_js=True,
    country="US",
    asp=True,
    retry=False,
    timeout=30000,
    rendering_wait=5000
))

html_content = result.scrape_result['content']

# %%
def extract_json_from_html(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    script_tags = soup.find_all('script')

    json_data_list = []

    for script in script_tags:
        script_content = script.string
        if script_content:
            # Use a regular expression to find JSON-like content
            json_pattern = re.compile(r'({.*})', re.DOTALL)
            matches = json_pattern.findall(script_content)
            for match in matches:
                try:
                    json_data = json.loads(match)
                    json_data_list.append(json_data)
                except json.JSONDecodeError:
                    pass  # Ignore invalid JSON

    return json_data_list

json_data_list = extract_json_from_html(html_content)

# %%
file_path = r'C:\Users\SudheerRChinthala\circana\Srikanth\Data\SamsungJSONData.json'
with open(file_path, 'w') as json_file:
    for json_data in json_data_list:
        json.dump(json_data, json_file, indent=4)

# %%
json_data_list
# Out:
# [{'rua.upush': 'false',
#   'rua.cpush': 'true',
#   'rua.upre': 'false',
#   'rua.cpre': 'false',
#   'rua.uprl': 'false',
#   'rua.cprl': 'false',
#   'rua.cprf': 'false',
#   'rua.trans': 'SJ-c22a6b90-39b3-4833-9c25-d185d0e12364',
#   'rua.cook': 'false',
#   'rua.ims': 'false',
#   'rua.ufprl': 'false',
#   'rua.cfprl': 'false',
#   'rua.isuxp': 'false',
#   'rua.texp': 'norulematch'},
#  {'gnbLeftModelList': [{'displayName': 'Shop',
#     'englishName': 'shop',
#     'linkType': 'move',
#     'displayFlag': 'Y',
#     'mobileOnlyFlag': 'N',
#     'menuPosition': 'left',
#     'apiUseFlag': False,
#     'ftImageUseFlag1': False,
#     'ftImageUseFlag2': False,
#     'ftImageUseFlag3': False,
#     'ftImageUseFlag4': False,
#     'ftImageUseFlag5': False,
#     'ftImageUseFlag6': False,
#     'ftImageUseFlag7': False,
#     'ftImageUseFlag8': False,
#     'ftImageUseFlag9': False,
#     'hasChildren': True,
#     'layoutType': 'l1l2spread',
#     'containerAlignment': 'left',
#     'level1ColumnList': [[{'displayName': 'New & Featured',
#        'englishName': 'new and featured',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'groupCode': 'none',
#        'typeCode': 'none',
#        'layoutColumn': '1',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'AI Products',
#          'englishName': 'ai products',
#          'linkType': 'move',
#          'linkUrl': '/in/ai-products/all-ai-products/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'true',
#          'badgeType': 'new',
#          'badgeText': 'NEW',
#          'badgePeriod': '20240430|20240630',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'Offers',
#        'englishName': 'offers',
#        'linkType': 'move',
#        'linkUrl': '/in/offer/online/samsung-fest/',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '2',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'All Offers',
#          'englishName': 'All Offers',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Fab Grab Fest ',
#          'englishName': 'fab grab fest',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/fab-grab-fest/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'true',
#          'badgeType': 'eco',
#          'badgeText': 'Live',
#          'badgePeriod': '20240904|20241031',
#          'isBadgeDisplay': True,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Mobile Offers',
#          'englishName': 'Mobile Offers',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/mobiles/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Television Offers',
#          'englishName': 'Television Offers',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/television-soundbar/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Refrigerator Offers',
#          'englishName': 'Refrigerator Offers',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/refrigerators/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Washing Machine Offers',
#          'englishName': 'Washing Machine Offers',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/washing-machines/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Laptop & Computing Offers',
#          'englishName': 'Laptop and Computing Offers',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/laptops-monitors/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Samsung Live',
#          'englishName': 'Samsung Live',
#          'linkType': 'move',
#          'linkUrl': '/in/samsung-live/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Samsung Shop App',
#          'englishName': 'Samsung Shop App',
#          'linkType': 'new',
#          'linkUrl': 'https://play.google.com/store/apps/details?id=com.samsung.ecomm',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'Why buy from Samsung',
#        'englishName': 'why buy from samsung',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '3',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'Overview',
#          'englishName': 'overview',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/online/why-buy-from-samsung/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Samsung Finance+',
#          'englishName': 'samsung finance plus',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/online/finance-plus/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Samsung Axis Bank Credit Card',
#          'englishName': 'samsung axis bank credit card',
#          'linkType': 'move',
#          'linkUrl': '/in/samsung-card/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Samsung Wallet',
#          'englishName': 'Samsung Wallet',
#          'linkType': 'move',
#          'linkUrl': '/in/apps/samsung-wallet/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Samsung Care+',
#          'englishName': 'Samsung Care',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/samsung-care-plus/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Delivery & Installation',
#          'englishName': 'Delivery and Installation',
#          'linkType': 'move',
#          'linkUrl': '/in/shop-faq/delivery-and-installations/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Mobiles Trade-in',
#          'englishName': 'Mobiles Trade-in',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/exchange/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Smart Club Loyalty Program',
#          'englishName': 'Smart Club Loyalty Program',
#          'linkType': 'move',
#          'linkUrl': '/in/microsite/smart-club/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Samsung Referral Advantage',
#          'englishName': 'samsung referral advantage',
#          'linkType': 'move',
#          'linkUrl': '/in/microsite/shop-referral/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Samsung BKC',
#          'englishName': 'Samsung BKC',
#          'linkType': 'move',
#          'linkUrl': '/in/store/samsung-bkc/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'Exclusive Discount Programs',
#        'englishName': 'Exclusive Discount Programs',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '5',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'Corporate Employee Program',
#          'englishName': 'Corporate Employee Program',
#          'linkType': 'move',
#          'linkUrl': '/in/multistore/corporate/prelogin/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Samsung Student Advantage',
#          'englishName': 'Samsung Student Advantage',
#          'linkType': 'move',
#          'linkUrl': '/in/offer/student-discount/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Government Employees',
#          'englishName': 'Government Employees',
#          'linkType': 'move',
#          'linkUrl': '/in/multistore/corporate/prelogin/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Defence Purchase Program',
#          'englishName': 'Defence Purchase Program',
#          'linkType': 'move',
#          'linkUrl': '/in/microsite/defence-purchase-program/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}]],
#     'ftbadgeDisplay1': False,
#     'ftbadgeDisplay2': False,
#     'ftbadgeDisplay3': False,
#     'ftbadgeDisplay4': False,
#     'ftbadgeDisplay5': False,
#     'ftbadgeDisplay6': False,
#     'ftbadgeDisplay7': False,
#     'ftbadgeDisplay8': False,
#     'ftbadgeDisplay9': False},
#    {'displayName': 'AI',
#     'englishName': 'ai',
#     'linkType': 'move',
#     'linkUrl': '/in/galaxy-ai/',
#     'displayFlag': 'Y',
#     'mobileOnlyFlag': 'N',
#     'menuPosition': 'left',
#     'apiUseFlag': False,
#     'ftImageUseFlag1': False,
#     'ftImageUseFlag2': False,
#     'ftImageUseFlag3': False,
#     'ftImageUseFlag4': False,
#     'ftImageUseFlag5': False,
#     'ftImageUseFlag6': False,
#     'ftImageUseFlag7': False,
#     'ftImageUseFlag8': False,
#     'ftImageUseFlag9': False,
#     'hasChildren': True,
#     'level1List': [{'displayName': 'AI for All',
#       'englishName': 'ai for all',
#       'linkType': 'move',
#       'linkUrl': '/in/ai-products/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Galaxy AI',
#       'englishName': 'galaxy ai',
#       'linkType': 'move',
#       'linkUrl': '/in/galaxy-ai/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Samsung AI TV',
#       'englishName': 'samsung ai tv',
#       'linkType': 'move',
#       'linkUrl': '/in/tvs/8k-tv/highlights/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Bespoke AI',
#       'englishName': 'bespoke ai',
#       'linkType': 'move',
#       'linkUrl': '/in/home-appliances/bespoke-home/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'All AI Products',
#       'englishName': 'all ai products',
#       'linkType': 'move',
#       'linkUrl': '/in/ai-products/all-ai-products/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'groupCode': 'none',
#       'typeCode': 'none',
#       'layoutColumn': '1',
#       'hasChildren': False}],
#     'layoutType': 'l1only',
#     'ftImageAreaTitle': 'New & Featured',
#     'containerAlignment': 'left',
#     'ftbadgeDisplay1': False,
#     'ftbadgeDisplay2': False,
#     'ftbadgeDisplay3': False,
#     'ftbadgeDisplay4': False,
#     'ftbadgeDisplay5': False,
#     'ftbadgeDisplay6': False,
#     'ftbadgeDisplay7': False,
#     'ftbadgeDisplay8': False,
#     'ftbadgeDisplay9': False},
#    {'displayName': 'Mobile',
#     'englishName': 'mobile',
#     'linkType': 'move',
#     'linkUrl': '/in/mobile/',
#     'displayFlag': 'Y',
#     'mobileOnlyFlag': 'N',
#     'menuPosition': 'left',
#     'groupCode': '20000000',
#     'apiUseFlag': False,
#     'ftImageUseFlag1': True,
#     'ftImageUseFlag2': True,
#     'ftImageUseFlag3': True,
#     'ftImageUseFlag4': True,
#     'ftImageUseFlag5': True,
#     'ftImageUseFlag6': True,
#     'ftImageUseFlag7': True,
#     'ftImageUseFlag8': True,
#     'ftImageUseFlag9': True,
#     'ftImageUrl1': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_Q6_168x136_mo.png',
#     'ftImageUrlDesktop1': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_Q6_168x136_mo.png?$84_68_PNG$',
#     'ftImageUrlMobile1': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_Q6_168x136_mo.png?$168_136_PNG$',
#     'ftImageUrlWithPreset1': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_Q6_168x136_mo.png?$LazyLoad_Home_PNG$',
#     'ftImageAlt1': 'Galaxy Z Fold6',
#     'ftImageAltEng1': 'galaxy z fold6',
#     'ftDescription1': 'Galaxy Z Fold6',
#     'ftDescriptionEng1': 'galaxy z fold6',
#     'ftLinkUrl1': '/in/smartphones/galaxy-z-fold6/',
#     'ftLinkType1': 'move',
#     'hasChildren': True,
#     'level1List': [{'displayName': 'Discover Mobiles',
#       'englishName': 'discover mobiles',
#       'linkType': 'move',
#       'linkUrl': '/in/mobile/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Galaxy AI',
#       'englishName': 'galaxy ai',
#       'linkType': 'move',
#       'linkUrl': '/in/galaxy-ai/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Galaxy Smartphone',
#       'englishName': 'galaxy smartphone',
#       'linkType': 'move',
#       'linkUrl': '/in/smartphones/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Galaxy Tab',
#       'englishName': 'galaxy tab',
#       'linkType': 'move',
#       'linkUrl': '/in/tablets/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Galaxy Book',
#       'englishName': 'galaxy book and laptops',
#       'linkType': 'move',
#       'linkUrl': '/in/galaxy-book/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Galaxy Watch',
#       'englishName': 'galaxy watch',
#       'linkType': 'move',
#       'linkUrl': '/in/watches/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Galaxy Buds',
#       'englishName': 'galaxy buds',
#       'linkType': 'move',
#       'linkUrl': '/in/audio-sound/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Galaxy Accessories',
#       'englishName': 'galaxy accessories',
#       'linkType': 'move',
#       'linkUrl': '/in/mobile-accessories/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'One UI',
#       'englishName': 'one ui',
#       'linkType': 'move',
#       'linkUrl': '/in/one-ui/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Samsung Health',
#       'englishName': 'samsung health',
#       'linkType': 'move',
#       'linkUrl': '/in/apps/samsung-health/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Apps & Services',
#       'englishName': 'apps and services',
#       'linkType': 'move',
#       'linkUrl': '/in/apps/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False},
#      {'displayName': 'Why Galaxy',
#       'englishName': 'why galaxy',
#       'linkType': 'move',
#       'linkUrl': '/in/mobile/why-galaxy/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'hasChildren': False},
#      {'displayName': 'Switch to Galaxy',
#       'englishName': 'switch to galaxy',
#       'linkType': 'move',
#       'linkUrl': '/in/mobile/switch-to-galaxy/',
#       'displayFlag': 'Y',
#       'mobileOnlyFlag': 'N',
#       'layoutColumn': '1',
#       'hasChildren': False}],
#     'layoutType': 'l1only',
#     'ftImageUrl2': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_B6_168x136_mo.png',
#     'ftImageAlt2': 'Galaxy Z Flip6',
#     'ftImageAltEng2': 'galaxy z flip6',
#     'ftDescription2': 'Galaxy Z Flip6',
#     'ftDescriptionEng2': 'galaxy z flip6',
#     'ftLinkType2': 'move',
#     'ftLinkUrl2': '/in/smartphones/galaxy-z-flip6/',
#     'ftImageUrl3': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E3_168x136_mo.png',
#     'ftImageAlt3': 'Galaxy S24 Ultra',
#     'ftImageAltEng3': 'galaxy s24 ultra',
#     'ftDescription3': 'Galaxy S24 Ultra',
#     'ftDescriptionEng3': 'galaxy s24 ultra',
#     'ftLinkType3': 'move',
#     'ftLinkUrl3': '/in/smartphones/galaxy-s24-ultra/',
#     'ftImageUrl4': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E1E2_168x136_mo.png',
#     'ftImageAlt4': 'Galaxy S24 | S24+',
#     'ftImageAltEng4': 'galaxy s24 and s24 plus',
#     'ftDescription4': 'Galaxy S24 | S24+',
#     'ftDescriptionEng4': 'galaxy s24 and s24 plus',
#     'ftLinkType4': 'move',
#     'ftLinkUrl4': '/in/smartphones/galaxy-s24/',
#     'ftImageUrl5': '//images.samsung.com/is/image/samsung/assets/in/gnb/A55_168x136.png',
#     'ftImageAlt5': 'Galaxy A55 5G',
#     'ftImageAltEng5': 'galaxy a55 5g',
#     'ftDescription5': 'Galaxy A55 5G',
#     'ftDescriptionEng5': 'galaxy a55 5g',
#     'ftLinkType5': 'new',
#     'ftLinkUrl5': '/in/smartphones/galaxy-a/galaxy-a55-5g-awesome-iceblue-256gb-sm-a556elbgins/',
#     'ftImageUrl6': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_TabS9_168x136_mo.png',
#     'ftImageAlt6': 'Galaxy Tab S9 Series',
#     'ftImageAltEng6': 'galaxy tab s9 series',
#     'ftDescription6': 'Galaxy Tab S9 Series',
#     'ftDescriptionEng6': 'galaxy tab s9 series',
#     'ftLinkType6': 'move',
#     'ftLinkUrl6': '/in/tablets/galaxy-tab-s/galaxy-tab-s9-5g-graphite-256gb-sm-x716bzaeinu/',
#     'ftImageUrl7': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/WatchUltra_GNB_mo_168x136.png',
#     'ftImageAlt7': 'Galaxy Watch Ultra',
#     'ftImageAltEng7': 'galaxy watch ultra',
#     'ftDescription7': 'Galaxy Watch Ultra',
#     'ftDescriptionEng7': 'galaxy watch ultra',
#     'ftLinkType7': 'move',
#     'ftLinkUrl7': '/in/watches/galaxy-watch/galaxy-watch-ultra-titanium-gray-lte-sm-l705fdaains/',
#     'ftImageUrl8': '//images.samsung.com/is/image/samsung/assets/in/gnb/168x136_Buds3.png',
#     'ftImageAlt8': 'Galaxy Buds3',
#     'ftImageAltEng8': 'galaxy buds3',
#     'ftDescription8': 'Galaxy Buds3',
#     'ftDescriptionEng8': 'galaxy buds3',
#     'ftLinkType8': 'move',
#     'ftLinkUrl8': '/in/audio-sound/galaxy-buds/galaxy-buds3-silver-sm-r530nzaainu/',
#     'ftImageUrl9': '//images.samsung.com/is/image/samsung/assets/in/home/168x136_GB4-Pre-Order.png',
#     'ftImageAlt9': 'Galaxy Book4 Ultra',
#     'ftImageAltEng9': 'galaxy book4 ultra',
#     'ftDescription9': 'Galaxy Book4 Ultra',
#     'ftDescriptionEng9': 'galaxy book4 ultra',
#     'ftLinkType9': 'move',
#     'ftLinkUrl9': '/in/computers/galaxy-book/galaxy-book4-ultra-16-inch-ultra-7-16gb-1tb-np960xgl-xg1in/',
#     'ftImageAreaTitle': 'New & Featured',
#     'containerAlignment': 'left',
#     'ftImageUrlDesktop2': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_B6_168x136_mo.png?$84_68_PNG$',
#     'ftImageUrlDesktop3': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E3_168x136_mo.png?$84_68_PNG$',
#     'ftImageUrlDesktop4': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E1E2_168x136_mo.png?$84_68_PNG$',
#     'ftImageUrlDesktop5': '//images.samsung.com/is/image/samsung/assets/in/gnb/A55_168x136.png?$84_68_PNG$',
#     'ftImageUrlDesktop6': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_TabS9_168x136_mo.png?$84_68_PNG$',
#     'ftImageUrlDesktop7': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/WatchUltra_GNB_mo_168x136.png?$84_68_PNG$',
#     'ftImageUrlDesktop8': '//images.samsung.com/is/image/samsung/assets/in/gnb/168x136_Buds3.png?$84_68_PNG$',
#     'ftImageUrlDesktop9': '//images.samsung.com/is/image/samsung/assets/in/home/168x136_GB4-Pre-Order.png?$84_68_PNG$',
#     'ftImageUrlMobile2': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_B6_168x136_mo.png?$168_136_PNG$',
#     'ftImageUrlMobile3': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E3_168x136_mo.png?$168_136_PNG$',
#     'ftImageUrlMobile4': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E1E2_168x136_mo.png?$168_136_PNG$',
#     'ftImageUrlMobile5': '//images.samsung.com/is/image/samsung/assets/in/gnb/A55_168x136.png?$168_136_PNG$',
#     'ftImageUrlMobile6': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_TabS9_168x136_mo.png?$168_136_PNG$',
#     'ftImageUrlMobile7': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/WatchUltra_GNB_mo_168x136.png?$168_136_PNG$',
#     'ftImageUrlMobile8': '//images.samsung.com/is/image/samsung/assets/in/gnb/168x136_Buds3.png?$168_136_PNG$',
#     'ftImageUrlMobile9': '//images.samsung.com/is/image/samsung/assets/in/home/168x136_GB4-Pre-Order.png?$168_136_PNG$',
#     'ftImageUrlWithPreset2': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_B6_168x136_mo.png?$LazyLoad_Home_PNG$',
#     'ftImageUrlWithPreset3': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E3_168x136_mo.png?$LazyLoad_Home_PNG$',
#     'ftImageUrlWithPreset4': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E1E2_168x136_mo.png?$LazyLoad_Home_PNG$',
#     'ftImageUrlWithPreset5': '//images.samsung.com/is/image/samsung/assets/in/gnb/A55_168x136.png?$LazyLoad_Home_PNG$',
#     'ftImageUrlWithPreset6': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_TabS9_168x136_mo.png?$LazyLoad_Home_PNG$',
#     'ftImageUrlWithPreset7': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/WatchUltra_GNB_mo_168x136.png?$LazyLoad_Home_PNG$',
#     'ftImageUrlWithPreset8': '//images.samsung.com/is/image/samsung/assets/in/gnb/168x136_Buds3.png?$LazyLoad_Home_PNG$',
#     'ftImageUrlWithPreset9': '//images.samsung.com/is/image/samsung/assets/in/home/168x136_GB4-Pre-Order.png?$LazyLoad_Home_PNG$',
#     'ftDataList': [{'ftImageUseFlag': True,
#       'ftImageUrl': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_Q6_168x136_mo.png',
#       'ftImageAlt': 'Galaxy Z Fold6',
#       'ftImageAltEng': 'galaxy z fold6',
#       'ftDescription': 'Galaxy Z Fold6',
#       'ftDescriptionEng': 'galaxy z fold6',
#       'ftLinkType': 'move',
#       'ftLinkUrl': '/in/smartphones/galaxy-z-fold6/',
#       'ftBadgeFlag': 'true',
#       'ftBadgeText': 'NEW',
#       'ftBadgeType': 'new',
#       'ftBadgePeriod': '20240702|20241231',
#       'ftImageUrlDesktop': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_Q6_168x136_mo.png?$84_68_PNG$',
#       'ftImageUrlMobile': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_Q6_168x136_mo.png?$168_136_PNG$',
#       'ftImageUrlWithPreset': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_Q6_168x136_mo.png?$LazyLoad_Home_PNG$',
#       'ftBadgeDisplay': True},
#      {'ftImageUseFlag': True,
#       'ftImageUrl': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_B6_168x136_mo.png',
#       'ftImageAlt': 'Galaxy Z Flip6',
#       'ftImageAltEng': 'galaxy z flip6',
#       'ftDescription': 'Galaxy Z Flip6',
#       'ftDescriptionEng': 'galaxy z flip6',
#       'ftLinkType': 'move',
#       'ftLinkUrl': '/in/smartphones/galaxy-z-flip6/',
#       'ftBadgeFlag': 'true',
#       'ftBadgeText': 'NEW',
#       'ftBadgeType': 'new',
#       'ftBadgePeriod': '20240702|20241231',
#       'ftImageUrlDesktop': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_B6_168x136_mo.png?$84_68_PNG$',
#       'ftImageUrlMobile': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_B6_168x136_mo.png?$168_136_PNG$',
#       'ftImageUrlWithPreset': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/GNB_B6_168x136_mo.png?$LazyLoad_Home_PNG$',
#       'ftBadgeDisplay': True},
#      {'ftImageUseFlag': True,
#       'ftImageUrl': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E3_168x136_mo.png',
#       'ftImageAlt': 'Galaxy S24 Ultra',
#       'ftImageAltEng': 'galaxy s24 ultra',
#       'ftDescription': 'Galaxy S24 Ultra',
#       'ftDescriptionEng': 'galaxy s24 ultra',
#       'ftLinkType': 'move',
#       'ftLinkUrl': '/in/smartphones/galaxy-s24-ultra/',
#       'ftImageUrlDesktop': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E3_168x136_mo.png?$84_68_PNG$',
#       'ftImageUrlMobile': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E3_168x136_mo.png?$168_136_PNG$',
#       'ftImageUrlWithPreset': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E3_168x136_mo.png?$LazyLoad_Home_PNG$',
#       'ftBadgeDisplay': False},
#      {'ftImageUseFlag': True,
#       'ftImageUrl': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E1E2_168x136_mo.png',
#       'ftImageAlt': 'Galaxy S24 | S24+',
#       'ftImageAltEng': 'galaxy s24 and s24 plus',
#       'ftDescription': 'Galaxy S24 | S24+',
#       'ftDescriptionEng': 'galaxy s24 and s24 plus',
#       'ftLinkType': 'move',
#       'ftLinkUrl': '/in/smartphones/galaxy-s24/',
#       'ftImageUrlDesktop': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E1E2_168x136_mo.png?$84_68_PNG$',
#       'ftImageUrlMobile': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E1E2_168x136_mo.png?$168_136_PNG$',
#       'ftImageUrlWithPreset': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_E1E2_168x136_mo.png?$LazyLoad_Home_PNG$',
#       'ftBadgeDisplay': False},
#      {'ftImageUseFlag': True,
#       'ftImageUrl': '//images.samsung.com/is/image/samsung/assets/in/gnb/A55_168x136.png',
#       'ftImageAlt': 'Galaxy A55 5G',
#       'ftImageAltEng': 'galaxy a55 5g',
#       'ftDescription': 'Galaxy A55 5G',
#       'ftDescriptionEng': 'galaxy a55 5g',
#       'ftLinkType': 'new',
#       'ftLinkUrl': '/in/smartphones/galaxy-a/galaxy-a55-5g-awesome-iceblue-256gb-sm-a556elbgins/',
#       'ftImageUrlDesktop': '//images.samsung.com/is/image/samsung/assets/in/gnb/A55_168x136.png?$84_68_PNG$',
#       'ftImageUrlMobile': '//images.samsung.com/is/image/samsung/assets/in/gnb/A55_168x136.png?$168_136_PNG$',
#       'ftImageUrlWithPreset': '//images.samsung.com/is/image/samsung/assets/in/gnb/A55_168x136.png?$LazyLoad_Home_PNG$',
#       'ftBadgeDisplay': False},
#      {'ftImageUseFlag': True,
#       'ftImageUrl': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_TabS9_168x136_mo.png',
#       'ftImageAlt': 'Galaxy Tab S9 Series',
#       'ftImageAltEng': 'galaxy tab s9 series',
#       'ftDescription': 'Galaxy Tab S9 Series',
#       'ftDescriptionEng': 'galaxy tab s9 series',
#       'ftLinkType': 'move',
#       'ftLinkUrl': '/in/tablets/galaxy-tab-s/galaxy-tab-s9-5g-graphite-256gb-sm-x716bzaeinu/',
#       'ftImageUrlDesktop': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_TabS9_168x136_mo.png?$84_68_PNG$',
#       'ftImageUrlMobile': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_TabS9_168x136_mo.png?$168_136_PNG$',
#       'ftImageUrlWithPreset': '//images.samsung.com/is/image/samsung/assets/in/2404/gnb/GNB_TabS9_168x136_mo.png?$LazyLoad_Home_PNG$',
#       'ftBadgeDisplay': False},
#      {'ftImageUseFlag': True,
#       'ftImageUrl': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/WatchUltra_GNB_mo_168x136.png',
#       'ftImageAlt': 'Galaxy Watch Ultra',
#       'ftImageAltEng': 'galaxy watch ultra',
#       'ftDescription': 'Galaxy Watch Ultra',
#       'ftDescriptionEng': 'galaxy watch ultra',
#       'ftLinkType': 'move',
#       'ftLinkUrl': '/in/watches/galaxy-watch/galaxy-watch-ultra-titanium-gray-lte-sm-l705fdaains/',
#       'ftBadgeFlag': 'true',
#       'ftBadgeText': 'NEW',
#       'ftBadgeType': 'new',
#       'ftBadgePeriod': '20240702|20241231',
#       'ftImageUrlDesktop': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/WatchUltra_GNB_mo_168x136.png?$84_68_PNG$',
#       'ftImageUrlMobile': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/WatchUltra_GNB_mo_168x136.png?$168_136_PNG$',
#       'ftImageUrlWithPreset': '//images.samsung.com/is/image/samsung/assets/in/2407/gnb/WatchUltra_GNB_mo_168x136.png?$LazyLoad_Home_PNG$',
#       'ftBadgeDisplay': True},
#      {'ftImageUseFlag': True,
#       'ftImageUrl': '//images.samsung.com/is/image/samsung/assets/in/gnb/168x136_Buds3.png',
#       'ftImageAlt': 'Galaxy Buds3',
#       'ftImageAltEng': 'galaxy buds3',
#       'ftDescription': 'Galaxy Buds3',
#       'ftDescriptionEng': 'galaxy buds3',
#       'ftLinkType': 'move',
#       'ftLinkUrl': '/in/audio-sound/galaxy-buds/galaxy-buds3-silver-sm-r530nzaainu/',
#       'ftBadgeFlag': 'true',
#       'ftBadgeText': 'NEW',
#       'ftBadgeType': 'new',
#       'ftBadgePeriod': '20240702|20241231',
#       'ftImageUrlDesktop': '//images.samsung.com/is/image/samsung/assets/in/gnb/168x136_Buds3.png?$84_68_PNG$',
#       'ftImageUrlMobile': '//images.samsung.com/is/image/samsung/assets/in/gnb/168x136_Buds3.png?$168_136_PNG$',
#       'ftImageUrlWithPreset': '//images.samsung.com/is/image/samsung/assets/in/gnb/168x136_Buds3.png?$LazyLoad_Home_PNG$',
#       'ftBadgeDisplay': True},
#      {'ftImageUseFlag': True,
#       'ftImageUrl': '//images.samsung.com/is/image/samsung/assets/in/home/168x136_GB4-Pre-Order.png',
#       'ftImageAlt': 'Galaxy Book4 Ultra',
#       'ftImageAltEng': 'galaxy book4 ultra',
#       'ftDescription': 'Galaxy Book4 Ultra',
#       'ftDescriptionEng': 'galaxy book4 ultra',
#       'ftLinkType': 'move',
#       'ftLinkUrl': '/in/computers/galaxy-book/galaxy-book4-ultra-16-inch-ultra-7-16gb-1tb-np960xgl-xg1in/',
#       'ftImageUrlDesktop': '//images.samsung.com/is/image/samsung/assets/in/home/168x136_GB4-Pre-Order.png?$84_68_PNG$',
#       'ftImageUrlMobile': '//images.samsung.com/is/image/samsung/assets/in/home/168x136_GB4-Pre-Order.png?$168_136_PNG$',
#       'ftImageUrlWithPreset': '//images.samsung.com/is/image/samsung/assets/in/home/168x136_GB4-Pre-Order.png?$LazyLoad_Home_PNG$',
#       'ftBadgeDisplay': False}],
#     'ftbadgeFlag1': 'true',
#     'ftbadgeText1': 'NEW',
#     'ftbadgeType1': 'new',
#     'ftbadgePeriod1': '20240702|20241231',
#     'ftbadgeFlag2': 'true',
#     'ftbadgeText2': 'NEW',
#     'ftbadgeType2': 'new',
#     'ftbadgePeriod2': '20240702|20241231',
#     'ftbadgeFlag7': 'true',
#     'ftbadgeText7': 'NEW',
#     'ftbadgeType7': 'new',
#     'ftbadgePeriod7': '20240702|20241231',
#     'ftbadgeFlag8': 'true',
#     'ftbadgeText8': 'NEW',
#     'ftbadgeType8': 'new',
#     'ftbadgePeriod8': '20240702|20241231',
#     'ftbadgeDisplay1': True,
#     'ftbadgeDisplay2': True,
#     'ftbadgeDisplay3': False,
#     'ftbadgeDisplay4': False,
#     'ftbadgeDisplay5': False,
#     'ftbadgeDisplay6': False,
#     'ftbadgeDisplay7': True,
#     'ftbadgeDisplay8': True,
#     'ftbadgeDisplay9': False},
#    {'displayName': 'TV & AV',
#     'englishName': 'tv and av',
#     'linkType': 'move',
#     'displayFlag': 'Y',
#     'mobileOnlyFlag': 'N',
#     'menuPosition': 'left',
#     'groupCode': '21000000',
#     'apiUseFlag': False,
#     'ftImageUseFlag1': False,
#     'ftImageUseFlag2': False,
#     'ftImageUseFlag3': False,
#     'ftImageUseFlag4': False,
#     'ftImageUseFlag5': False,
#     'ftImageUseFlag6': False,
#     'ftImageUseFlag7': False,
#     'ftImageUseFlag8': False,
#     'ftImageUseFlag9': False,
#     'hasChildren': True,
#     'layoutType': 'l1l2spread',
#     'containerAlignment': 'left',
#     'level1ColumnList': [[{'displayName': 'Recommended',
#        'englishName': 'recommended',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '1',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'All About TV',
#          'englishName': 'all about tv',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/tv-buying-guide/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Why Samsung TV',
#          'englishName': 'why samsung smart tv',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/why-samsung-tv/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Why 8K TVs',
#          'englishName': 'why 8k tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/8k-tv/highlights/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Why Neo QLED',
#          'englishName': 'why neo qled',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/qled-tv/highlights/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Why Samsung OLED',
#          'englishName': 'why samsung oled',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/oled-tv/highlights/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Why Neo QLED for gaming',
#          'englishName': 'why neo qled for gaming',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/gaming-tv/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'true',
#          'badgeType': 'hot',
#          'badgeText': 'HOT',
#          'badgePeriod': '20221218|20230330',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Why Samsung Smart TV',
#          'englishName': 'smart TV',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/smart-tv/highlights/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'TVs',
#        'englishName': 'tvs',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '2',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'All TVs',
#          'englishName': 'all tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/all-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Neo QLED',
#          'englishName': 'neo qled',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/qled-tv/?neo-qled-8k+neo-qled-4k',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'OLED',
#          'englishName': 'OLED',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/all-tvs/?oled-tv',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'true',
#          'badgeType': 'new',
#          'badgeText': 'NEW',
#          'badgePeriod': '20230603|20230831',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'QLED 4K',
#          'englishName': 'qled 4k',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/qled-tv/?qled-4k',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'groupCode': '21000000',
#          'typeCode': '21010000',
#          'subTypeCode': '21010500',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Crystal 4K UHD',
#          'englishName': 'Crystal 4K UHD',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/all-tvs/?crystal-uhd',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'The Frame',
#          'englishName': 'the frame',
#          'linkType': 'move',
#          'linkUrl': '/in/lifestyle-tvs/the-frame/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'The Serif',
#          'englishName': 'the serif',
#          'linkType': 'move',
#          'linkUrl': '/in/lifestyle-tvs/the-serif/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'TV Accessories',
#          'englishName': 'tv accessories',
#          'linkType': 'move',
#          'linkUrl': '/in/tv-accessories/all-tv-accessories/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Discover TVs',
#          'englishName': 'discover tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'QLED 8K',
#          'englishName': 'qled 8k',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/all-tvs/?qled-8k',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'Y',
#          'groupCode': '21000000',
#          'typeCode': '21010000',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'UHD 4K',
#          'englishName': 'uhd 4k',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/uhd-4k-tv/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'Y',
#          'groupCode': '21000000',
#          'typeCode': '21010000',
#          'subTypeCode': '21010200',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Full HD/HD TVs',
#          'englishName': 'full hd and hd tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/full-hd-tv/?full-hd-tv+hd-tv',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'Y',
#          'groupCode': '21000000',
#          'typeCode': '21010000',
#          'subTypeCode': '21010300',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'TV by Size',
#        'englishName': 'tv by size',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '3',
#        'hasChildren': True,
#        'level2List': [{'displayName': '2.47 m (98) TVs',
#          'englishName': '2m 47cm 98 inch tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/2m-47cm-98-inch-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': '2.16 m (85) TVs',
#          'englishName': '2m 16cm 85 inch tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/2m-16cm-85-inch-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': '1.89 m (75) TVs',
#          'englishName': '1m 89cm 75 inch tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/1m-89cm-75-inch-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': '1.63 m (65) TVs',
#          'englishName': '1m 63cm 65 inch tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/1m-63cm-65-inch-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': '1.38 m (55) TVs',
#          'englishName': '1m 38cm 55 inch tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/1m-38cm-55-inch-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'groupCode': '21000000',
#          'typeCode': '21010000',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': '1.25 m (50) TVs',
#          'englishName': '1m 25cm 50 inch tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/1m-25cm-50-inch-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'groupCode': '21000000',
#          'typeCode': '21010000',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': '1.08 m (43) TVs',
#          'englishName': '1m 08cm 43 inch tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/1m-08cm-43-inch-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'groupCode': '21000000',
#          'typeCode': '21010000',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': '80 cm (32) TVs',
#          'englishName': '80cm 32 inch tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/80cm-32-inch-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'groupCode': '21000000',
#          'typeCode': '21010000',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'All TVs',
#          'englishName': 'all tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/all-tvs/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'TV by Resolution',
#        'englishName': 'tv by resolution',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '4',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'QLED 8K',
#          'englishName': 'qled 8k',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/all-tvs/?qled-8k',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'UHD 4K',
#          'englishName': 'uhd 4k',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/uhd-4k-tv/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Full HD/HD TVs',
#          'englishName': 'full hd hd tvs',
#          'linkType': 'move',
#          'linkUrl': '/in/tvs/full-hd-tv/?full-hd-tv+hd-tv',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'Projectors',
#        'englishName': 'projectors',
#        'linkType': 'move',
#        'linkUrl': '/in/projectors/all-projectors/',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '5',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'The Premiere',
#          'englishName': 'the premiere',
#          'linkType': 'move',
#          'linkUrl': '/in/projectors/all-projectors/?the-premiere',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'The Freestyle',
#          'englishName': 'the freestyle',
#          'linkType': 'move',
#          'linkUrl': '/in/projectors/the-freestyle/lff3c-the-freestyle-2nd-gen-sp-lff3claxxxl/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'All Projectors',
#          'englishName': 'all projectors',
#          'linkType': 'move',
#          'linkUrl': '/in/projectors/all-projectors/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'true',
#          'badgeType': 'new',
#          'badgeText': 'NEW',
#          'badgePeriod': '20220418|20220725',
#          'isBadgeDisplay': False}]}],
#      [{'displayName': 'Sound Devices',
#        'englishName': 'sound devices',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '6',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'Discover Sound\xa0Devices',
#          'englishName': 'discover sound devices',
#          'linkType': 'move',
#          'linkUrl': '/in/audio-devices/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Soundbar',
#          'englishName': 'soundbar',
#          'linkType': 'move',
#          'linkUrl': '/in/audio-devices/soundbar/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'groupCode': '21000000',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Music Frame',
#          'englishName': 'music frame',
#          'linkType': 'move',
#          'linkUrl': '/in/audio-devices/music-frame/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Sound Tower',
#          'englishName': 'sound tower',
#          'linkType': 'move',
#          'linkUrl': '/in/audio-devices/sound-tower/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'groupCode': '21000000',
#          'isBadgeDisplay': False},
#         {'displayName': 'All Sound\xa0Devices',
#          'englishName': 'all sound devices',
#          'linkType': 'move',
#          'linkUrl': '/in/audio-devices/all-audio-devices/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False}]}]],
#     'ftbadgeDisplay1': False,
#     'ftbadgeDisplay2': False,
#     'ftbadgeDisplay3': False,
#     'ftbadgeDisplay4': False,
#     'ftbadgeDisplay5': False,
#     'ftbadgeDisplay6': False,
#     'ftbadgeDisplay7': False,
#     'ftbadgeDisplay8': False,
#     'ftbadgeDisplay9': False},
#    {'displayName': 'Home Appliances',
# ...
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Digital Service Center',
#          'englishName': 'digital service center',
#          'linkType': 'move',
#          'linkUrl': 'https://samsungdigitalservicecenter.com/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'How-to Videos',
#          'englishName': 'how to videos',
#          'linkType': 'new',
#          'linkUrl': 'https://samsungdigitalservicecenter.com/DIY-videos',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'SHOP FAQ',
#          'englishName': 'shop faq',
#          'linkType': 'new',
#          'linkUrl': '/in/shop-faq/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'Repairs & Warranty',
#        'englishName': 'repairs and warranty',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '2',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'Warranty Information',
#          'englishName': 'warranty information',
#          'linkType': 'move',
#          'linkUrl': '/in/support/warranty/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Service Locator',
#          'englishName': 'service locator',
#          'linkType': 'move',
#          'linkUrl': '/in/support/service-center/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Book a Repair',
#          'englishName': 'book a repair',
#          'linkType': 'move',
#          'linkUrl': '/in/mypage/myproducts/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Track Repair',
#          'englishName': 'track repair',
#          'linkType': 'move',
#          'linkUrl': '/in/mypage/myrepair/track-repair/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Out of warranty Repair Charges',
#          'englishName': 'out of warranty repair charges',
#          'linkType': 'move',
#          'linkUrl': '/in/support/out-of-warranty-repair-charges/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Phone spare part cost',
#          'englishName': 'phone spare part cost',
#          'linkType': 'move',
#          'linkUrl': '/in/support/spare-part-pricing-list-for-repair/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'Contact',
#        'englishName': 'contact',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '3',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'WhatsApp Us',
#          'englishName': 'whatsapp us',
#          'linkType': 'move',
#          'linkUrl': 'https://wa.me/91180057267864?text=hi',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Email',
#          'englishName': 'email',
#          'linkType': 'new',
#          'linkUrl': 'https://samsungdigitalservicecenter.com/?action=email',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Call',
#          'englishName': 'call',
#          'linkType': 'move',
#          'linkUrl': '/in/support/contact/#contactinfo',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Sign Language',
#          'englishName': 'sign language',
#          'linkType': 'move',
#          'linkUrl': 'https://wa.me/91180057267864?text=hi',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Care for clean India',
#          'englishName': 'care for clean india',
#          'linkType': 'move',
#          'linkUrl': '/in/microsite/care-for-clean-india/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Community',
#          'englishName': 'Community',
#          'linkType': 'move',
#          'linkUrl': 'https://r2.community.samsung.com/t5/Tips-How-to/bg-p/in-community-blog-cs?page=1&tab=recent_topics',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}],
#      [{'displayName': 'Additional Info',
#        'englishName': 'additional info',
#        'linkType': 'move',
#        'displayFlag': 'Y',
#        'mobileOnlyFlag': 'N',
#        'layoutColumn': '4',
#        'hasChildren': True,
#        'level2List': [{'displayName': 'News & Alerts',
#          'englishName': 'news and alerts',
#          'linkType': 'move',
#          'linkUrl': '/in/support/newsalert/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'Smart Switch',
#          'englishName': 'smart switch',
#          'linkType': 'move',
#          'linkUrl': '/in/apps/smart-switch/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'},
#         {'displayName': 'TV spare part cost',
#          'englishName': 'tv spare part cost',
#          'linkType': 'move',
#          'linkUrl': '/in/support/tv-spare-part-price/',
#          'displayFlag': 'Y',
#          'mobileOnlyFlag': 'N',
#          'badgeFlag': 'false',
#          'isBadgeDisplay': False,
#          'shopLiveUseFlag': 'false'}]}]],
#     'ftbadgeDisplay1': False,
#     'ftbadgeDisplay2': False,
#     'ftbadgeDisplay3': False,
#     'ftbadgeDisplay4': False,
#     'ftbadgeDisplay5': False,
#     'ftbadgeDisplay6': False,
#     'ftbadgeDisplay7': False,
#     'ftbadgeDisplay8': False,
#     'ftbadgeDisplay9': False},
#    {'displayName': 'For Business',
#     'englishName': 'for business',
#     'linkType': 'move',
#     'linkUrl': '/in/business/',
#     'displayFlag': 'Y',
#     'mobileOnlyFlag': 'N',
#     'menuPosition': 'right',
#     'apiUseFlag': False,
#     'ftImageUseFlag1': False,
#     'ftImageUseFlag2': False,
#     'ftImageUseFlag3': False,
#     'ftImageUseFlag4': False,
#     'ftImageUseFlag5': False,
#     'ftImageUseFlag6': False,
#     'ftImageUseFlag7': False,
#     'ftImageUseFlag8': False,
#     'ftImageUseFlag9': False,
#     'hasChildren': False,
#     'level1List': [],
#     'layoutType': 'l1only',
#     'ftImageAreaTitle': 'New & Featured',
#     'containerAlignment': 'left',
#     'ftbadgeDisplay1': False,
#     'ftbadgeDisplay2': False,
#     'ftbadgeDisplay3': False,
#     'ftbadgeDisplay4': False,
#     'ftbadgeDisplay5': False,
#     'ftbadgeDisplay6': False,
#     'ftbadgeDisplay7': False,
#     'ftbadgeDisplay8': False,
#     'ftbadgeDisplay9': False}],
#   'beforeLoginModel': {'displayName': 'Before Login',
#    'englishName': 'before_login',
#    'apiUseFlag': False,
#    'ftImageUseFlag1': False,
#    'ftImageUseFlag2': False,
#    'ftImageUseFlag3': False,
#    'ftImageUseFlag4': False,
#    'ftImageUseFlag5': False,
#    'ftImageUseFlag6': False,
#    'ftImageUseFlag7': False,
#    'ftImageUseFlag8': False,
#    'ftImageUseFlag9': False,
#    'hasChildren': True,
#    'level1List': [{'displayName': 'Orders',
#      'englishName': 'orders',
#      'linkType': 'move',
#      'linkUrl': '/in/web/search-orders/',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'hasChildren': False},
#     {'displayName': 'Product Registration\n',
#      'englishName': 'product registration',
#      'linkType': 'move',
#      'linkUrl': '/in/mypage/myproducts/',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'layoutColumn': '1',
#      'hasChildren': False},
#     {'displayName': 'Digital Service Center',
#      'englishName': 'digital service center',
#      'linkType': 'move',
#      'linkUrl': 'https://www.samsungdigitalservicecenter.com/',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'hasChildren': False}],
#    'ftbadgeDisplay1': False,
#    'ftbadgeDisplay2': False,
#    'ftbadgeDisplay3': False,
#    'ftbadgeDisplay4': False,
#    'ftbadgeDisplay5': False,
#    'ftbadgeDisplay6': False,
#    'ftbadgeDisplay7': False,
#    'ftbadgeDisplay8': False,
#    'ftbadgeDisplay9': False},
#   'afterLoginModel': {'displayName': 'After Login',
#    'englishName': 'after_login',
#    'apiUseFlag': False,
#    'ftImageUseFlag1': False,
#    'ftImageUseFlag2': False,
#    'ftImageUseFlag3': False,
#    'ftImageUseFlag4': False,
#    'ftImageUseFlag5': False,
#    'ftImageUseFlag6': False,
#    'ftImageUseFlag7': False,
#    'ftImageUseFlag8': False,
#    'ftImageUseFlag9': False,
#    'hasChildren': True,
#    'level1List': [{'displayName': 'My Page',
#      'englishName': 'my page',
#      'linkType': 'move',
#      'linkUrl': '/in/mypage/',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'hasChildren': False},
#     {'displayName': 'Orders',
#      'englishName': 'orders',
#      'linkType': 'move',
#      'linkUrl': '/in/web/mypage/orders/',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'hasChildren': False},
#     {'displayName': 'Wishlist',
#      'englishName': 'wishlist',
#      'linkType': 'move',
#      'linkUrl': '/in/web/mypage/wishlist/',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'hasChildren': False},
#     {'displayName': 'Smart Club',
#      'englishName': 'smart club',
#      'linkType': 'move',
#      'linkUrl': '/in/web/loyalty-home/',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'hasChildren': False},
#     {'displayName': 'Product Registration\n',
#      'englishName': 'product registration',
#      'linkType': 'move',
#      'linkUrl': '/in/mypage/myproducts/',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'layoutColumn': '1',
#      'hasChildren': False},
#     {'displayName': 'Digital Service Center',
#      'englishName': 'digital service center',
#      'linkType': 'move',
#      'linkUrl': 'https://www.samsungdigitalservicecenter.com/',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'hasChildren': False},
#     {'displayName': 'Community',
#      'englishName': 'community',
#      'linkType': 'move',
#      'linkUrl': 'https://r2.community.samsung.com/t5/India/ct-p/in?profile.language=en',
#      'displayFlag': 'Y',
#      'mobileOnlyFlag': 'N',
#      'hasChildren': False}],
#    'ftbadgeDisplay1': False,
#    'ftbadgeDisplay2': False,
#    'ftbadgeDisplay3': False,
#    'ftbadgeDisplay4': False,
#    'ftbadgeDisplay5': False,
#    'ftbadgeDisplay6': False,
#    'ftbadgeDisplay7': False,
#    'ftbadgeDisplay8': False,
#    'ftbadgeDisplay9': False},
#   'gnbUtilModel': {'isLogin': 'Y',
#    'isCart': 'Y',
#    'shopIntegrationFlag': 'GPv2',
#    'loginLinkUrl': 'https://account.samsung.com/accounts/v1/Samsung_com_IN/signInGate',
#    'logoutUrl': 'https://account.samsung.com/accounts/v1/Samsung_com_IN/signOutGate',
#    'stgloginLinkUrl': 'https://stg-account.samsung.com/accounts/v1/Samsung_com_IN/signInGate',
#    'stglogoutUrl': 'https://stg-account.samsung.com/accounts/v1/Samsung_com_IN/signOutGate',
#    'preqaloginLinkUrl': 'https://stg-account.samsung.com/accounts/v1/Samsung_com_IN/signInGate',
#    'preqalogoutUrl': 'https://stg-account.samsung.com/accounts/v1/Samsung_com_IN/signOutGate',
#    'SAsignOutURL': '/aemapi/v6/data-login/afterLogout.in.json',
#    'loginAccountServiceId': '28xws2p2v3',
#    'SAserviceName': 'SAMSUNG',
#    'countryCode': 'IN',
#    'countryIsoCode': 'IND',
#    'languageCode': 'en',
#    'registURL': '/aemapi/v6/data-login/afterLogin.in.json',
#    'stgStoreDomain': 'https://s6ro-live.samsung.com/in/api',
#    'preqaStoreDomain': 'https://in.ecom-qa.samsung.com',
#    'preqa2StoreDomain': 'https://in.ecom-stg.samsung.com',
#    'uatStoreDomain': 'https://hshopfront.samsung.com/in/api',
#    'orderUrl': '/in/web/my-orders/',
#    'cartUrl': '/in/web/cart/',
#    'useFullCartUrl': False,
#    'emailActivationURL': '/aemapi/v6/data-login/emailActivationURL.in.json',
#    'storeDomain': 'https://www.samsung.com/in/api',
#    'trackOrderUrl': '/in/web/search-orders/',
#    'privacyTag1': '<a href=\'/in/info/privacy/\' target=\'_blank\' class=\'link-text\' title="Open in a New Window">',
#    'privacyTag2': '</a>',
#    'wishlistUrl': '/in/web/my-wishlist/',
#    'saStoreDomain': 'https://p6-qaweb-sa.samsung.com/in/api'},
#   'homeLinkPath': '/in/',
#   'language': 'en_IN'},
#  {'@context': 'http://schema.org/',
#   '@type': '3DModel',
#   'image': 'https://images.samsung.com/is/image/samsung/p6pim/in/ls32dm700uwxxl/gallery/in-smart-m7-32m70d-ls32dm700uwxxl-541962049',
#   'name': 'front Black',
#   'encoding': [{'@type': 'MediaObject',
#     'contentUrl': 'https://images.samsung.com/is/content/samsung/p6pim/in/ls32dm700uwxxl/gallery/in-smart-m7-32m70d-ls32dm700uwxxl-541962021.glb',
#     'encodingFormat': 'model/gltf - binary'},
#    {'@type': 'MediaObject',
#     'contentUrl': 'https://images.samsung.com/is/content/samsung/p6pim/in/ls32dm700uwxxl/gallery/in-smart-m7-32m70d-ls32dm700uwxxl-541962022.usdz',
#     'encodingFormat': 'model /vnd.usdz+zip'}]},
#  {'@context': 'http://schema.org',
#   '@type': 'Product',
#   'brand': {'@type': 'Brand', 'name': 'Samsung'},
#   '@id': 'https://www.samsung.com/in/monitors/smart/smart-monitor-m7-32-inch-smart-tv-apps-ls32dm700uwxxl/',
#   'name': '80 cm M70D UHD 4K Smart Monitor with Smart TV experience',
#   'image': 'https://images.samsung.com/is/image/samsung/p6pim/in/ls32dm700uwxxl/gallery/in-smart-m7-32m70d-ls32dm700uwxxl-thumb-541962050',
#   'description': 'Embedded Smart TV Apps -Netflix, YouTube, Amazon Prime video, Samsung TV plus and more.\nRemote control and built-in 10 W speakers with adaptive sound\nMultiple Ports - USB Type-C, HDMI and USB-A\nIoT Hub, Workout Tracker, Microsoft 365, Mouse & Keyboard control',
#   'sku': 'LS32DM700UW',
#   'offers': {'@type': 'Offer',
#    'url': 'https://www.samsung.com/in/monitors/smart/smart-monitor-m7-32-inch-smart-tv-apps-ls32dm700uwxxl/',
#    'priceCurrency': 'INR',
#    'availability': 'InStock',
#    'price': '30999'}},
#  {'@context': 'http://schema.org',
#   '@type': 'BreadcrumbList',
#   'itemListElement': [{'@type': 'ListItem',
#     'name': 'Home',
#     'item': 'https://www.samsung.com/in/',
#     'position': 1},
#    {'@type': 'ListItem',
#     'name': 'Monitors',
#     'item': 'https://www.samsung.com/in/monitors/',
#     'position': 2},
#    {'@type': 'ListItem',
#     'name': 'Smart Monitor',
#     'item': 'https://www.samsung.com/in/monitors/smart/',
#     'position': 3},
#    {'@type': 'ListItem',
#     'name': '80 cm M70D UHD 4K Smart Monitor with Smart TV experience',
#     'item': '',
#     'position': 4}]},
#  {'@context': 'http://schema.org',
#   '@type': 'WebPage',
#   'name': 'Shop 80 cm M70D UHD 4K Smart Monitor | Samsung India | Samsung India',
#   'url': 'https://www.samsung.com/in/monitors/smart/smart-monitor-m7-32-inch-smart-tv-apps-ls32dm700uwxxl/'}]
