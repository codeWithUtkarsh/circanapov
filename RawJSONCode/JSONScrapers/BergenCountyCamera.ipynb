# %%
import requests
from bs4 import BeautifulSoup
from scrapfly import ScrapflyClient, ScrapeConfig
import re
import json

api_key = 'scp-live-01fc8534987042f4a2fe553c5cf6a2df'
scrapfly = ScrapflyClient(key=api_key, max_concurrency=2)
url = 'https://www.beachcamera.com/products/panasonic-lumix-fz80d-compact-camera-20-1200mm-zoom-lens'
result = scrapfly.scrape(ScrapeConfig(
    url=url,
    render_js=True,
    country="US",
    asp=True,
    retry=False,
    timeout=30000,
    rendering_wait=5000
))

html_content = result.scrape_result['content']

# %%
def extract_json_from_html(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    script_tags = soup.find_all('script')

    json_data_list = []

    for script in script_tags:
        script_content = script.string
        if script_content:
            # Use a regular expression to find JSON-like content
            json_pattern = re.compile(r'({.*})', re.DOTALL)
            matches = json_pattern.findall(script_content)
            for match in matches:
                try:
                    json_data = json.loads(match)
                    json_data_list.append(json_data)
                except json.JSONDecodeError:
                    pass  # Ignore invalid JSON

    return json_data_list

json_data_list = extract_json_from_html(html_content)

# %%
file_path = r'C:\Users\SudheerRChinthala\circana\Srikanth\Data\BergenCountyCameraJSONData.json'
with open(file_path, 'w') as json_file:
    for json_data in json_data_list:
        json.dump(json_data, json_file, indent=4)

# %%
json_data_list
# Out:
# [{'gtm_id': 'GTM-KGXNM8T',
#   'event_config': {'cart_reconcile': True,
#    'cart_view': True,
#    'checkout_complete': True,
#    'checkout_step': True,
#    'collection_view': True,
#    'defers_collection_loading': False,
#    'defers_search_results_loading': False,
#    'product_add_to_cart': False,
#    'product_add_to_cart_ajax': True,
#    'product_remove_from_cart': True,
#    'product_select': True,
#    'product_view': True,
#    'search_results_view': True,
#    'user': True,
#    'save_order_notes': True},
#   'gtm_suite_script': 'https://shopify-gtm-suite.getelevar.com/shops/c7a48983ba8712879b19791a566edea8c0c29e0e/3.8.0/gtm-suite.js',
#   'consent_enabled': False,
#   'apex_domain': None},
#  {'data_layer_listener_script': 'https://shopify-gtm-suite.getelevar.com/shops/c7a48983ba8712879b19791a566edea8c0c29e0e/3.8.0/events.js',
#   'ss_url': None,
#   'signing_key': None,
#   'myshopify_domain': None},
#  {'shopId': 50435555511,
#   'countryCode': 'US',
#   'currencyCode': 'USD',
#   'merchantCapabilities': ['supports3DS'],
#   'merchantId': 'gid://shopify/Shop/50435555511',
#   'merchantName': 'Beach Camera',
#   'requiredBillingContactFields': ['postalAddress', 'email', 'phone'],
#   'requiredShippingContactFields': ['postalAddress', 'email', 'phone'],
#   'shippingType': 'shipping',
#   'supportedNetworks': ['visa',
#    'masterCard',
#    'amex',
#    'discover',
#    'elo',
#    'jcb'],
#   'total': {'type': 'pending', 'label': 'Beach Camera', 'amount': '1.00'},
#   'shopifyPaymentsEnabled': True,
#   'supportsSubscriptions': True},
#  {'accessToken': 'a862d499205eb9ae75dfe15efa685ea9',
#   'betas': ['rich-media-storefront-analytics'],
#   'domain': 'www.beachcamera.com',
#   'predictiveSearch': True,
#   'shopId': 50435555511,
#   'smart_payment_buttons_url': 'https://www.beachcamera.com/cdn/shopifycloud/payment-sheet/assets/latest/spb.en.js',
#   'dynamic_checkout_cart_url': 'https://www.beachcamera.com/cdn/shopifycloud/payment-sheet/assets/latest/dynamic-checkout-cart.en.js',
#   'locale': 'en'},
#  {},
#  {'pageType': 'product'},
#  {'a': 50435555511,
#   'offset': -14400,
#   'reqid': '3856213c-b485-41ef-9b56-a4ee5032fd4f-1727523996',
#   'pageurl': 'www.beachcamera.com/products/panasonic-lumix-fz80d-compact-camera-20-1200mm-zoom-lens',
#   'u': '83b8589fe786',
#   'p': 'product',
#   'rtyp': 'product',
#   'rid': 7780631380151},
#  {},
#  {'settings': {'sticky_header': False,
#    'live_search': {'enable': True,
#     'enable_images': True,
#     'enable_content': True,
#     'money_format': '${{amount}}',
#     'show_mobile_search_bar': True,
#     'context': {'view_all_results': 'View all results',
#      'view_all_products': 'View all products',
#      'content_results': {'title': 'Pages &amp; Posts',
#       'no_results': 'No results.'},
#      'no_results_products': {'title': 'No products for “*terms*”.',
#       'title_in_category': 'No products for “*terms*” in *category*.',
#       'message': 'Sorry, we couldn’t find any matches.'}}}}},
#  {'settings': {'cart_redirection': False,
#    'layout': 'layout--three-col',
#    'thumbnail_position': 'below',
#    'gallery_video_autoplay': True,
#    'gallery_video_looping': True,
#    'hover_zoom': 'disabled',
#    'click_to_zoom': 'always',
#    'money_format': '${{amount}}',
#    'swatches_enable': False,
#    'sold_out_options': 'hidden',
#    'select_first_available_variant': False,
#    'show_bc_related_products': True},
#   'context': {'select_variant': 'Please select a variant',
#    'product_available': 'Add to cart',
#    'product_sold_out': 'Sold out',
#    'product_unavailable': 'Unavailable'},
#   'product': {'id': 7780631380151,
#    'title': 'Panasonic Lumix FZ80D Compact Camera + 20-1200mm Zoom Lens',
#    'handle': 'panasonic-lumix-fz80d-compact-camera-20-1200mm-zoom-lens',
#    'description': '<h2 style="text-align: center;"><strong>Panasonic Lumix FZ80D Compact Camera + 20-1200mm Zoom Lens</strong></h2>\n<h3><strong>Product Highlight:</strong></h3>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">20mm wide-angle lens with 60x zoom for landscapes and macro details</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">2,360K-dot LVF with 0.74x magnification for glare-free viewing</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Amazing Video Quality for Fast-Paced Action with 4K Video and 4K Photo</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Post Focus lets you adjust focus after the shot</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">No More Blur, Even at 60x Zoom with the POWER O.I.S (Optical Image Stabilizer)</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">USB Type-C Battery Charging</span></p>\n<h3><strong>Product Feature:</strong></h3>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Taking Bridge Cameras to Another Level</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">The FZ80D enables you to capture incredibly clear moments near and far. The 20-1200mm zoom lens (35mm camera equivalent) gives you the ability to shoot landscapes and panoramas with a high level of detail. Clear, glare-resistant View Finder (2,360K dots); 4K video/photo; POWER O.I.S.; macro shooting</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Panoramas in Extraordinary Detail</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">20mm wide-angle lens creates breathtaking landscapes, with a powerful 60x zoom (35mm equivalent: 20-1200mm) to capture the big picture as well as fine details.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>An Always-Clear View, Even in Bright Sunlight</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">2,360K-dot. Large LVF 0.74x (35mm camera equivalent) ensures you\'ll see your screen without glare.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Amazing Video Quality for Fast-Paced Action</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">4K Video Mode records up to 4x resolution of Full HD; for incredible flexibility; 4K Photo feature lets you extract the perfect 8-megapixel photo out of 4K video and save it.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Shoot Now, Focus Later</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Post Focus feature gives you the power to touch the area you\'d like to be in focus, even after the shot has been taken.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>No More Blur, Even at 60x Zoom</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">The POWER O.I.S. (Optical Image Stabilizer) effectively suppresses hand-shake vibration at the tele-end.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Stunning Macro Photos</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Shoot incredibly vivid close-up shots of food, flowers, insects, and more with a minimum focusing distance of 1cm.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Intuitive Touch Control with 1,840k-dot Monitor</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">The 3.0-inch rear monitor with a high resolution of approximately 1,840k-dot features higher visibility even for sunny outdoor shooting. And, touch control immediately lets you to set focus to the subject by just touching it on the screen and you can even release the shutter.</span></p>\n<p style="paddi ...
#    'published_at': '2024-09-27T12:49:28-04:00',
#    'created_at': '2024-07-03T14:16:19-04:00',
#    'vendor': 'Panasonic',
#    'type': 'Point & Shoot Digital Cameras',
#    'tags': ['2092',
#     'Brand_Panasonic',
#     'Cameras with Free Memory Card!',
#     'Category_Point & Shoot Digital Cameras',
#     'Condition_New',
#     'Digital Cameras',
#     'Digital Cameras 14-19 MP',
#     'Free 2 Day Shipping',
#     'Panasonic',
#     'Photography',
#     'Point & Shoot Digital Cameras',
#     'Save on these great deals'],
#    'price': 47799,
#    'price_min': 47799,
#    'price_max': 47799,
#    'available': True,
#    'price_varies': False,
#    'compare_at_price': 47999,
#    'compare_at_price_min': 47999,
#    'compare_at_price_max': 47999,
#    'compare_at_price_varies': False,
#    'variants': [{'id': 43097540395191,
#      'title': 'Default Title',
#      'option1': 'Default Title',
#      'option2': None,
#      'option3': None,
#      'sku': 'PNDCFZ80D',
#      'requires_shipping': True,
#      'taxable': True,
#      'featured_image': None,
#      'available': True,
#      'name': 'Panasonic Lumix FZ80D Compact Camera + 20-1200mm Zoom Lens',
#      'public_title': None,
#      'options': ['Default Title'],
#      'price': 47799,
#      'weight': 640,
#      'compare_at_price': 47999,
#      'inventory_management': 'shopify',
#      'barcode': '885170432253',
#      'requires_selling_plan': False,
#      'selling_plan_allocations': [],
#      'quantity_rule': {'min': 1, 'max': None, 'increment': 1}}],
#    'images': ['//www.beachcamera.com/cdn/shop/files/1019183_1.jpg?v=1720030579',
#     '//www.beachcamera.com/cdn/shop/files/1019184_2.jpg?v=1720030579',
#     '//www.beachcamera.com/cdn/shop/files/1019185_3.jpg?v=1720030579',
#     '//www.beachcamera.com/cdn/shop/files/1019186_4.jpg?v=1720030579',
#     '//www.beachcamera.com/cdn/shop/files/1019187_5.jpg?v=1720030579',
#     '//www.beachcamera.com/cdn/shop/files/1019188_6.jpg?v=1720030579',
#     '//www.beachcamera.com/cdn/shop/files/1019189_7.jpg?v=1720030579',
#     '//www.beachcamera.com/cdn/shop/files/1019190_8.jpg?v=1720030579',
#     '//www.beachcamera.com/cdn/shop/files/1019191_9.jpg?v=1720030579',
#     '//www.beachcamera.com/cdn/shop/files/1019192_10.jpg?v=1720030580',
#     '//www.beachcamera.com/cdn/shop/files/1019193_11.jpg?v=1720030580',
#     '//www.beachcamera.com/cdn/shop/files/1019194_12.jpg?v=1720030580',
#     '//www.beachcamera.com/cdn/shop/files/1019195_13.jpg?v=1720030580'],
#    'featured_image': '//www.beachcamera.com/cdn/shop/files/1019183_1.jpg?v=1720030579',
#    'options': ['Title'],
#    'media': [{'alt': None,
#      'id': 29342069162167,
#      'position': 1,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019183_1.jpg?v=1720030579'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019183_1.jpg?v=1720030579',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069194935,
#      'position': 2,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019184_2.jpg?v=1720030579'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019184_2.jpg?v=1720030579',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069227703,
#      'position': 3,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019185_3.jpg?v=1720030579'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019185_3.jpg?v=1720030579',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069260471,
#      'position': 4,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019186_4.jpg?v=1720030579'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019186_4.jpg?v=1720030579',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069293239,
#      'position': 5,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019187_5.jpg?v=1720030579'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019187_5.jpg?v=1720030579',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069326007,
#      'position': 6,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019188_6.jpg?v=1720030579'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019188_6.jpg?v=1720030579',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069358775,
#      'position': 7,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019189_7.jpg?v=1720030579'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019189_7.jpg?v=1720030579',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069391543,
#      'position': 8,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019190_8.jpg?v=1720030579'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019190_8.jpg?v=1720030579',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069424311,
#      'position': 9,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019191_9.jpg?v=1720030579'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019191_9.jpg?v=1720030579',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069457079,
#      'position': 10,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019192_10.jpg?v=1720030580'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019192_10.jpg?v=1720030580',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069489847,
#      'position': 11,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019193_11.jpg?v=1720030580'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019193_11.jpg?v=1720030580',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069522615,
#      'position': 12,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019194_12.jpg?v=1720030580'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019194_12.jpg?v=1720030580',
#      'width': 1500},
#     {'alt': None,
#      'id': 29342069555383,
#      'position': 13,
#      'preview_image': {'aspect_ratio': 1.0,
#       'height': 1500,
#       'width': 1500,
#       'src': '//www.beachcamera.com/cdn/shop/files/1019195_13.jpg?v=1720030580'},
#      'aspect_ratio': 1.0,
#      'height': 1500,
#      'media_type': 'image',
#      'src': '//www.beachcamera.com/cdn/shop/files/1019195_13.jpg?v=1720030580',
#      'width': 1500}],
#    'requires_selling_plan': False,
#    'selling_plan_groups': [],
#    'content': '<h2 style="text-align: center;"><strong>Panasonic Lumix FZ80D Compact Camera + 20-1200mm Zoom Lens</strong></h2>\n<h3><strong>Product Highlight:</strong></h3>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">20mm wide-angle lens with 60x zoom for landscapes and macro details</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">2,360K-dot LVF with 0.74x magnification for glare-free viewing</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Amazing Video Quality for Fast-Paced Action with 4K Video and 4K Photo</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Post Focus lets you adjust focus after the shot</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">No More Blur, Even at 60x Zoom with the POWER O.I.S (Optical Image Stabilizer)</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">USB Type-C Battery Charging</span></p>\n<h3><strong>Product Feature:</strong></h3>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Taking Bridge Cameras to Another Level</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">The FZ80D enables you to capture incredibly clear moments near and far. The 20-1200mm zoom lens (35mm camera equivalent) gives you the ability to shoot landscapes and panoramas with a high level of detail. Clear, glare-resistant View Finder (2,360K dots); 4K video/photo; POWER O.I.S.; macro shooting</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Panoramas in Extraordinary Detail</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">20mm wide-angle lens creates breathtaking landscapes, with a powerful 60x zoom (35mm equivalent: 20-1200mm) to capture the big picture as well as fine details.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>An Always-Clear View, Even in Bright Sunlight</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">2,360K-dot. Large LVF 0.74x (35mm camera equivalent) ensures you\'ll see your screen without glare.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Amazing Video Quality for Fast-Paced Action</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">4K Video Mode records up to 4x resolution of Full HD; for incredible flexibility; 4K Photo feature lets you extract the perfect 8-megapixel photo out of 4K video and save it.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Shoot Now, Focus Later</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Post Focus feature gives you the power to touch the area you\'d like to be in focus, even after the shot has been taken.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>No More Blur, Even at 60x Zoom</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">The POWER O.I.S. (Optical Image Stabilizer) effectively suppresses hand-shake vibration at the tele-end.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Stunning Macro Photos</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Shoot incredibly vivid close-up shots of food, flowers, insects, and more with a minimum focusing distance of 1cm.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Intuitive Touch Control with 1,840k-dot Monitor</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">The 3.0-inch rear monitor with a high resolution of approximately 1,840k-dot features higher visibility even for sunny outdoor shooting. And, touch control immediately lets you to set focus to the subject by just touching it on the screen and you can even release the shutter.</span></p>\n<p style="padding-l ...
#  {'recently_viewed_info': {'handle': 'panasonic-lumix-fz80d-compact-camera-20-1200mm-zoom-lens'},
#   'time': {'second': 'second',
#    'seconds': 'seconds',
#    'minute': 'minute',
#    'minutes': 'minutes',
#    'hour': 'hour',
#    'hours': 'hours',
#    'ago': 'ago'},
#   'product_card_settings': {'emphasize_price': True,
#    'sale_badge': False,
#    'sale_badge_style': 'percent'},
#   'currency': 'USD'},
#  {'cart_redirection': False, 'money_format': '${{amount}}'},
#  {'@context': 'http://schema.org',
#   '@type': 'BreadcrumbList',
#   'itemListElement': [{'@type': 'ListItem',
#     'position': 1,
#     'item': {'@id': 'https://www.beachcamera.com/collections',
#      'name': 'Collections'}},
#    {'@type': 'ListItem',
#     'position': 2,
#     'item': {'@id': 'https://www.beachcamera.com/collections/all-products',
#      'name': 'All products'}},
#    {'@type': 'ListItem',
#     'position': 3,
#     'item': {'@id': 'https://www.beachcamera.com/products/panasonic-lumix-fz80d-compact-camera-20-1200mm-zoom-lens',
#      'name': 'Panasonic Lumix FZ80D Compact Camera + 20-1200mm Zoom Lens'}}]},
#  {'@context': 'http://schema.org/',
#   '@type': 'Product',
#   'name': 'Panasonic Lumix FZ80D Compact Camera + 20-1200mm Zoom Lens',
#   'image': 'https://www.beachcamera.com/cdn/shop/files/1019183_1_1024x1024.jpg?v=1720030579',
#   'description': '<h2 style="text-align: center;"><strong>Panasonic Lumix FZ80D Compact Camera + 20-1200mm Zoom Lens</strong></h2>\n<h3><strong>Product Highlight:</strong></h3>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">20mm wide-angle lens with 60x zoom for landscapes and macro details</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">2,360K-dot LVF with 0.74x magnification for glare-free viewing</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Amazing Video Quality for Fast-Paced Action with 4K Video and 4K Photo</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Post Focus lets you adjust focus after the shot</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">No More Blur, Even at 60x Zoom with the POWER O.I.S (Optical Image Stabilizer)</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">USB Type-C Battery Charging</span></p>\n<h3><strong>Product Feature:</strong></h3>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Taking Bridge Cameras to Another Level</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">The FZ80D enables you to capture incredibly clear moments near and far. The 20-1200mm zoom lens (35mm camera equivalent) gives you the ability to shoot landscapes and panoramas with a high level of detail. Clear, glare-resistant View Finder (2,360K dots); 4K video/photo; POWER O.I.S.; macro shooting</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Panoramas in Extraordinary Detail</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">20mm wide-angle lens creates breathtaking landscapes, with a powerful 60x zoom (35mm equivalent: 20-1200mm) to capture the big picture as well as fine details.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>An Always-Clear View, Even in Bright Sunlight</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">2,360K-dot. Large LVF 0.74x (35mm camera equivalent) ensures you\'ll see your screen without glare.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Amazing Video Quality for Fast-Paced Action</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">4K Video Mode records up to 4x resolution of Full HD; for incredible flexibility; 4K Photo feature lets you extract the perfect 8-megapixel photo out of 4K video and save it.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Shoot Now, Focus Later</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Post Focus feature gives you the power to touch the area you\'d like to be in focus, even after the shot has been taken.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>No More Blur, Even at 60x Zoom</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">The POWER O.I.S. (Optical Image Stabilizer) effectively suppresses hand-shake vibration at the tele-end.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Stunning Macro Photos</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">Shoot incredibly vivid close-up shots of food, flowers, insects, and more with a minimum focusing distance of 1cm.</span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;"><strong>Intuitive Touch Control with 1,840k-dot Monitor</strong></span></p>\n<p style="padding-left: 30px;"><span style="font-size: 14px;">The 3.0-inch rear monitor with a high resolution of approximately 1,840k-dot features higher visibility even for sunny outdoor shooting. And, touch control immediately lets you to set focus to the subject by just touching it on the screen and you can even release the shutter.</span></p>\n<p style="paddin ...
#   'brand': {'@type': 'Thing', 'name': 'Panasonic'},
#   'sku': 'PNDCFZ80D',
#   'mpn': '885170432253',
#   'offers': {'@type': 'Offer',
#    'priceCurrency': 'USD',
#    'price': 477.99,
#    'availability': 'http://schema.org/InStock',
#    'url': 'https://www.beachcamera.com/products/panasonic-lumix-fz80d-compact-camera-20-1200mm-zoom-lens?variant=43097540395191',
#    'seller': {'@type': 'Organization', 'name': 'Beach Camera'},
#    'priceValidUntil': '2025-09-28'}},
#  {'@context': 'http://schema.org',
#   '@type': 'WebSite',
#   'name': 'Beach Camera',
#   'url': 'https://www.beachcamera.com'},
#  {'api_key': 'e8c74750-6aba-44e9-ae37-cc0532260261',
#   'merchant_id': '4146',
#   'merchant_group_id': '12683',
#   'locale': 'en_US'}]
